# %% [markdown]
# # Basic Dictionay Operations

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs (name, age, city).

# %%
dict1={'name':'Alice','age':30,'city':'UK'}
dict1.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 30), ('city', 'UK')])

# %% [markdown]
# 2. Create a dictionary and print the value of a specific key.

# %%
dict2={'name':'Bob','age':25,'city':'USA'}
dict2.get('age')
# Out:
# 25

# %% [markdown]
# 3. Make a dictionary and add a new key-value pair to it.

# %%
dict3={'name':'Charlie','age':35,'city':'Canada'}
dict3['voting']='yes'
dict3
# Out:
# {'name': 'Charlie', 'age': 35, 'city': 'Canada', 'voting': 'yes'}

# %% [markdown]
# 4. Create a dictionary and change the value of an existing key.

# %%
dict4={'name':'Jack','age':28,'city':'Australia'}
dict4['city']='Dublin'
dict4
# Out:
# {'name': 'Jack', 'age': 28, 'city': 'Dublin'}

# %% [markdown]
# 5. Create a dictionary and remove one key using pop().

# %%
dict5={'name':'john','age':22,'city':'India'}
dict5.pop('age')
dict5
# Out:
# {'name': 'john', 'city': 'India'}

# %% [markdown]
# 6. Create a dictionary and remove the last inserted item using popitem().

# %%
dict6={'name':'Kelli','age':27,'city':'US'}
dict6.popitem()
dict6
# Out:
# {'name': 'Kelli', 'age': 27}

# %% [markdown]
# 7. Create a dictionary and print all the keys.

# %%
dict7={'name':'Noha','age':32,'city':'Spain'}
dict7.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %% [markdown]
# 8. Create a dictionary and print all the values.

# %%
dict8={'mobile':'iPhone','price':99999,'stock':50,'brand':'Apple'}
dict8.values()
# Out:
# dict_values(['iPhone', 99999, 50, 'Apple'])

# %% [markdown]
# 9. Create a dictionary and print all the key-value items.

# %%
dict9={'product':'Laptop','price':150000,'stock':30}
dict9.items()
# Out:
# dict_items([('product', 'Laptop'), ('price', 150000), ('stock', 30)])

# %% [markdown]
# 10. Make a dictionary and check the number of items using len().

# %%
dict10={'employee':'Nick','age':40,'department':'HR'}
print(len(dict10))
# Out:
# 3

# %% [markdown]
# 11. Create a dictionary and check if a certain key exists (using "key" in dict).

# %%
dict11={'student':'Sofia','age':21,'course':'SOC'}
dict11.get('course')
dict11['age']
# Out:
# 21

# %% [markdown]
# 12. Create an empty dictionary and add two key-value pairs one by one.

# %%
dict12={}
dict12['fruit']='Apple'
dict12['quantity']=10
dict12['price']=50
dict12
# Out:
# {'fruit': 'Apple', 'quantity': 10, 'price': 50}

# %% [markdown]
# 13. Create a dictionary and update one key’s value using update().

# %%
dict13={'bike':'Yamaha','model':'FZ','year':2020}
dict13['year']=2021
dict13
# Out:
# {'bike': 'Yamaha', 'model': 'FZ', 'year': 2021}

# %% [markdown]
# 14. Create two dictionaries and combine them using update().

# %%
dict14={'name':'Jena','age':29,'city':'Germany'}
dict14_1={'name':'Jena','age':29,'city':'Germany'}
dict14_2=dict14|dict14_1
dict14_2
# Out:
# {'name': 'Jena', 'age': 29, 'city': 'Germany'}

# %% [markdown]
# 15. Make a dictionary and get the value of a key using get().

# %%
dict15={'name':'king','age':31,'city':'US'}
dict15.get('city')
# Out:
# 'US'

# %% [markdown]
# 16. Create a dictionary and print its type using type().

# %%
dict16={'product':'iPad','price':30000,'stock':20}
type(dict16)
# Out:
# dict

# %% [markdown]
# 17. Create a dictionary and replace one value with a new one.

# %%
dict17={'item':'iPad','price':25000,'stock':15}
dict17['price']=55000
dict17
# Out:
# {'item': 'iPad', 'price': 55000, 'stock': 15}

# %% [markdown]
# 18. Create a dictionary and clear all items using clear().

# %%
dict18={'device':'Laptop','brand':'Dell','price':80000}
dict18.clear()
dict18
# Out:
# {}

# %% [markdown]
# 19. Create a dictionary with numbers as keys and names as values. Print the dictionary.

# %%
dict19={'1':'one','2':'two','3':'three'}
dict19
# Out:
# {'1': 'one', '2': 'two', '3': 'three'}

# %% [markdown]
# 20. Create a dictionary and copy it into a new dictionary using copy().

# %%
dict20={'a':'A','b':'B','c':'C'}
dict21=dict20.copy()
dict21
# Out:
# {'a': 'A', 'b': 'B', 'c': 'C'}
